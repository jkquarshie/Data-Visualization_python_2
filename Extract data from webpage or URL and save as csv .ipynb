# %%
# !conda install -c anaconda xlrd --yes
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %% [markdown]
# Loading data using url

# %%
data_path = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx'

# %%
can_df = pd.read_excel(data_path, sheet_name='Canada by Citizenship',
                      skiprows=range(20), skipfooter=2)
can_df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2012  2013  \
# 0    Southern Asia  902  Developing regions    16  ...  2635  2004
# 1  Southern Europe  901   Developed regions     1  ...   620   603
# 2  Northern Africa  902  Developing regions    80  ...  3774  4331
# 3        Polynesia  902  Developing regions     0  ...     0     0
# 4  Southern Europe  901   Developed regions     0  ...     1     1
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
can_df.to_csv("immigration_canada.csv")

# %%
can_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 51 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         195 non-null    object
#  1   Coverage     195 non-null    object
#  2   OdName       195 non-null    object
#  3   AREA         195 non-null    int64
#  4   AreaName     195 non-null    object
#  5   REG          195 non-null    int64
#  6   RegName      195 non-null    object
#  7   DEV          195 non-null    int64
#  8   DevName      195 non-null    object
#  9   1980         195 non-null    int64
#  10  1981         195 non-null    int64
#  11  1982         195 non-null    int64
#  12  1983         195 non-null    int64
#  13  1984         195 non-null    int64
#  14  1985         195 non-null    int64
#  15  1986         195 non-null    int64
#  16  1987         195 non-null    int64
#  17  1988         195 non-null    int64
#  18  1989         195 non-null    int64
# ...

# %%
can_df.shape
# Out:
# (195, 51)

# %%
can_df.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'],
           axis = 1, inplace = True)
can_df.head(2)
# Out:
#         OdName AreaName          RegName             DevName  1980  1981  \
# 0  Afghanistan     Asia    Southern Asia  Developing regions    16    39
# 1      Albania   Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2012  2013  Unnamed: 43  Unnamed: 44  \
# 0    39    47    71   340  ...  2635  2004          NaN          NaN
# 1     0     0     0     0  ...   620   603          NaN          NaN
#
#    Unnamed: 45  Unnamed: 46  Unnamed: 47  Unnamed: 48  Unnamed: 49  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 50
# 0          NaN
# 1          NaN
#
# [2 rows x 46 columns]

# %%
can_df.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
can_df.columns
# Out:
# Index([    'Country',   'Continent',      'Region',     'DevName',
#                 1980,          1981,          1982,          1983,
#                 1984,          1985,          1986,          1987,
#                 1988,          1989,          1990,          1991,
#                 1992,          1993,          1994,          1995,
#                 1996,          1997,          1998,          1999,
#                 2000,          2001,          2002,          2003,
#                 2004,          2005,          2006,          2007,
#                 2008,          2009,          2010,          2011,
#                 2012,          2013, 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50'],
#       dtype='object')

# %%
can_df.head(2)
# Out:
#        Country Continent           Region             DevName  1980  1981  \
# 0  Afghanistan      Asia    Southern Asia  Developing regions    16    39
# 1      Albania    Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2012  2013  Unnamed: 43  Unnamed: 44  \
# 0    39    47    71   340  ...  2635  2004          NaN          NaN
# 1     0     0     0     0  ...   620   603          NaN          NaN
#
#    Unnamed: 45  Unnamed: 46  Unnamed: 47  Unnamed: 48  Unnamed: 49  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 50
# 0          NaN
# 1          NaN
#
# [2 rows x 46 columns]

# %%
import pyreadstat

# %%
gh = pd.read_spss('gha_r8_data_27oct20.sav')

# %%
gh.head()
# Out:
#     RESPNO URBRUR         REGION EA_SVC_A EA_SVC_B EA_SVC_C EA_SVC_D  \
# 0  GHA0001  Rural            OTI      Yes      Yes       No      Yes
# 1  GHA0002  Rural            OTI      Yes      Yes       No      Yes
# 2  GHA0003  Rural            OTI      Yes      Yes       No      Yes
# 3  GHA0004  Rural            OTI      Yes      Yes       No      Yes
# 4  GHA0005  Urban  GREATER ACCRA      Yes      Yes      Yes      Yes
#
#           EA_SVC_E EA_FAC_A EA_FAC_B  ...    Q114   Q115       Q116  \
# 0              Yes       No      Yes  ...  Female  Urban   Ewe/Anlo
# 1              Yes       No      Yes  ...    Male  Urban   Ewe/Anlo
# 2              Yes       No      Yes  ...    Male  Urban   Ewe/Anlo
# 3              Yes       No      Yes  ...  Female  Rural   Ewe/Anlo
# 4  Can't determine       No      Yes  ...  Female  Urban  Ga/Dangbe
#
#            Q117                                               Q118     Q119_1  \
# ...

# %%
gh.to_csv("round8_gh.csv")
